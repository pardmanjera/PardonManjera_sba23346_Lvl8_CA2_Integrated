# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
missing_value_formats = ["n.a.","?","NA","n/a", "na", "--"]

df = pd.read_csv('Employee_Attrition.csv', na_values = missing_value_formats)

# %%
df.head()
# Out:
#          Age Attrition     BusinessTravel    DailyRate  \
# 0  41.920786       Yes      Travel_Rarely   990.110009
# 1  51.589037        No  Travel_Frequently   276.776030
# 2  33.131540       Yes      Travel_Rarely  1204.158501
# 3  34.707073        No  Travel_Frequently  1352.752432
# 4  24.790188        No      Travel_Rarely   485.053333
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales          1.016716   1.770313  Life Sciences
# 1  Research & Development               NaN   1.035333  Life Sciences
# 2  Research & Development          2.198662   2.118801          Other
# 3                   Sales          2.937851   3.670674  Life Sciences
# 4  Research & Development          1.988953   1.120496        Medical
#
#    EmployeeCount  EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0       1.033298        1.054148  ...                  1.012832     95.612654
# ...

# %%
df.tail()
# Out:
#             Age Attrition     BusinessTravel   DailyRate  \
# 1465  37.421699        No  Travel_Frequently  914.061807
# 1466  34.957777        No                NaN  574.675152
# 1467  26.884296        No      Travel_Rarely  151.506083
# 1468        NaN        No  Travel_Frequently  995.977086
# 1469  38.133892        No      Travel_Rarely  703.677110
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1465  Research & Development         21.647903        NaN        Medical
# 1466  Research & Development          6.027683   1.122961        Medical
# 1467  Research & Development               NaN   3.478895  Life Sciences
# 1468         Human Resources          2.094496   2.956093        Medical
# 1469  Research & Development          7.231661   3.292684        Medical
#
#       EmployeeCount  EmployeeNumber  ...  RelationshipSatisfaction  \
# 1465       0.950166     2142.083554  ...                  3.020184
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# Descriptive Statistics

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1323.000000  1323.000000       1323.000000  1323.000000    1323.000000
# mean     36.635268   802.030050          9.091097     2.923447       0.999325
# std       9.882161   414.031025          8.177870     1.072203       0.099656
# min      14.544608    86.828045          0.750112     0.770362       0.628985
# 25%      29.624982   456.479553          2.147069     2.122706       0.931146
# 50%      34.951950   782.958705          6.920808     3.015658       0.998949
# 75%      42.748741  1130.577949         13.584900     3.700560       1.067371
# max      69.402515  1784.394456         33.684424     6.285161       1.290613
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1323.000000              1323.000000  1323.000000     1323.000000
# mean      1026.679166                 2.726443    65.647722        2.743028
# ...

# %%
df.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1323.000000      1323           1323  1323.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1065            890          NaN
# mean      36.635268       NaN            NaN   802.030050
# std        9.882161       NaN            NaN   414.031025
# min       14.544608       NaN            NaN    86.828045
# 25%       29.624982       NaN            NaN   456.479553
# 50%       34.951950       NaN            NaN   782.958705
# 75%       42.748741       NaN            NaN  1130.577949
# max       69.402515       NaN            NaN  1784.394456
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1323       1323.000000  1323.000000           1323
# unique                       3               NaN          NaN              6
# ...

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### remove some columns which have the same information, for example, daily rate, hourly rate monthly rate etc

# %%
to_remove = ['DailyRate', 'EmployeeCount', 'MonthlyIncome', 'MonthlyRate', 'Over18']
df.drop(columns = to_remove, inplace=True)
df.shape
# Out:
# (1470, 30)

# %% [markdown]
# ### renaming of colmns

# %%
new_columns = {'BusinessTravel': 'travel', 'Department': 'dpt',
       'DistanceFromHome': 'distance', 'EducationField':'field', 
       'EmployeeNumber': 'ID', 'EnvironmentSatisfaction': 'environment', 'HourlyRate': 'rate',
       'JobInvolvement': 'involement', 'JobLevel': 'level', 'JobRole': 'role', 'JobSatisfaction': 'job',
       'MaritalStatus': 'marriage', 'NumCompaniesWorked': 'companies',
       'PercentSalaryHike': 'hike', 'PerformanceRating': 'rating',
       'RelationshipSatisfaction': 'rlation', 'StandardHours': 'hours', 'StockOptionLevel': 'stocks',
       'TotalWorkingYears': 'yrsworked', 'TrainingTimesLastYear': 'training', 'WorkLifeBalance': 'wlb',
       'YearsAtCompany': 'yrs', 'YearsInCurrentRole': 'yrsrole', 'YearsSinceLastPromotion': 'yrspromo',
       'YearsWithCurrManager': 'yrsmanager'}

df.rename(columns = new_columns, inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'travel', 'dpt', 'distance', 'Education', 'field',
#        'ID', 'environment', 'Gender', 'rate', 'involement', 'level', 'role',
#        'job', 'marriage', 'companies', 'OverTime', 'hike', 'rating', 'rlation',
#        'hours', 'stocks', 'yrsworked', 'training', 'wlb', 'yrs', 'yrsrole',
#        'yrspromo', 'yrsmanager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1323 non-null   float64
#  1   Attrition    1323 non-null   object
#  2   travel       1323 non-null   object
#  3   dpt          1323 non-null   object
#  4   distance     1323 non-null   float64
#  5   Education    1323 non-null   float64
#  6   field        1323 non-null   object
#  7   ID           1323 non-null   float64
#  8   environment  1323 non-null   float64
#  9   Gender       1323 non-null   object
#  10  rate         1323 non-null   float64
#  11  involement   1323 non-null   float64
#  12  level        1323 non-null   float64
#  13  role         1323 non-null   object
#  14  job          1323 non-null   float64
#  15  marriage     1323 non-null   object
#  16  companies    1323 non-null   float64
#  17  OverTime     1323 non-null   object
# ...

# %%
unique_counts = df.nunique()

print(unique_counts)
# Out:
# Age            1323
# Attrition         2
# travel            3
# dpt               3
# distance       1323
# Education      1323
# field             6
# ID             1323
# environment    1323
# Gender            2
# rate           1323
# involement     1323
# level          1323
# role              9
# job            1323
# marriage          3
# companies      1146
# OverTime          2
# hike           1323
# rating         1323
# rlation        1323
# hours          1323
# stocks          772
# yrsworked      1314
# training       1275
# wlb            1323
# yrs            1281
# yrsrole        1106
# yrspromo        795
# yrsmanager     1087
# dtype: int64

# %% [markdown]
# dealing with duplicate rows

# %%
duplicate_rows = df[df.duplicated()]

print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, travel, dpt, distance, Education, field, ID, environment, Gender, rate, involement, level, role, job, marriage, companies, OverTime, hike, rating, rlation, hours, stocks, yrsworked, training, wlb, yrs, yrsrole, yrspromo, yrsmanager]
# Index: []
#
# [0 rows x 30 columns]

# %%
print(df.isnull().sum())
# Out:
# Age            147
# Attrition      147
# travel         147
# dpt            147
# distance       147
# Education      147
# field          147
# ID             147
# environment    147
# Gender         147
# rate           147
# involement     147
# level          147
# role           147
# job            147
# marriage       147
# companies      147
# OverTime       147
# hike           147
# rating         147
# rlation        147
# hours          147
# stocks         147
# yrsworked      147
# training       147
# wlb            147
# yrs            147
# yrsrole        147
# yrspromo       147
# yrsmanager     147
# dtype: int64

# %%
data = df.dropna()

# %%
data.shape
# Out:
# (67, 30)

# %% [markdown]
# . dropping null values for this dataset ends up with us loosing most of the data hence it is not the best method of handling missing values

# %%
float_columns = df.select_dtypes(include=['float']).columns

df[float_columns] = df[float_columns].apply(lambda x: x.fillna(x.mean()))

# %%
object_columns = df.select_dtypes(include=['object']).columns

df[object_columns] = df[object_columns].apply(lambda x: x.fillna(x.mode()[0]))

# %%
print(df.isnull().sum())
# Out:
# Age            0
# Attrition      0
# travel         0
# dpt            0
# distance       0
# Education      0
# field          0
# ID             0
# environment    0
# Gender         0
# rate           0
# involement     0
# level          0
# role           0
# job            0
# marriage       0
# companies      0
# OverTime       0
# hike           0
# rating         0
# rlation        0
# hours          0
# stocks         0
# yrsworked      0
# training       0
# wlb            0
# yrs            0
# yrsrole        0
# yrspromo       0
# yrsmanager     0
# dtype: int64

# %%
df.describe()
# Out:
#                Age     distance    Education           ID  environment  \
# count  1470.000000  1470.000000  1470.000000  1470.000000  1470.000000
# mean     36.635268     9.091097     2.923447  1026.679166     2.726443
# std       9.374687     7.757915     1.017143   579.131037     1.071667
# min      14.544608     0.750112     0.770362     1.054148     0.759655
# 25%      30.357410     2.265377     2.200839   539.350448     1.956071
# 50%      36.262348     7.871631     2.923447  1026.679166     2.726443
# 75%      41.714666    11.525354     3.598201  1469.776833     3.501999
# max      69.402515    33.684424     6.285161  2530.919375     5.254672
#
#               rate   involement        level          job    companies  ...  \
# count  1470.000000  1470.000000  1470.000000  1470.000000  1470.000000  ...
# mean     65.647722     2.743028     2.058270     2.715272     2.654394  ...
# std      20.367184     0.726254     1.069143     1.087896     2.380110  ...
# ...

# %% [markdown]
# for several columns the values are in float, these have to be rounded off for easy handling in data preparation, statistical analysis and even machine learning modelling.

# %%
decimal_columns = df.select_dtypes(include=['float']).columns

print("Columns with decimal values:", list(decimal_columns))
# Out:
# Columns with decimal values: ['Age', 'distance', 'Education', 'ID', 'environment', 'rate', 'involement', 'level', 'job', 'companies', 'hike', 'rating', 'rlation', 'hours', 'stocks', 'yrsworked', 'training', 'wlb', 'yrs', 'yrsrole', 'yrspromo', 'yrsmanager']

# %%
df[decimal_columns] = df[decimal_columns].round().astype(int)

# %%
df.head()
# Out:
#    Age Attrition             travel                     dpt  distance  \
# 0   42       Yes      Travel_Rarely                   Sales         1
# 1   52        No  Travel_Frequently  Research & Development         9
# 2   33       Yes      Travel_Rarely  Research & Development         2
# 3   35        No  Travel_Frequently                   Sales         3
# 4   25        No      Travel_Rarely  Research & Development         2
#
#    Education          field  ID  environment  Gender  ...  rlation  hours  \
# 0          2  Life Sciences   1            2    Male  ...        1     96
# 1          1  Life Sciences   2            3    Male  ...        4     85
# 2          2          Other   4            4    Male  ...        2     76
# 3          4  Life Sciences   5            4  Female  ...        3     76
# 4          1        Medical   7            1    Male  ...        3     73
#
#    stocks yrsworked  training wlb  yrs yrsrole  yrspromo  yrsmanager
# ...

# %%
df.shape
# Out:
# (1470, 30)

# %%
df.dtypes.value_counts()
# Out:
# int32     22
# object     8
# dtype: int64

# %% [markdown]
# dealing with duplicate rows

# %%
duplicate_rows = df[df.duplicated()]

print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, travel, dpt, distance, Education, field, ID, environment, Gender, rate, involement, level, role, job, marriage, companies, OverTime, hike, rating, rlation, hours, stocks, yrsworked, training, wlb, yrs, yrsrole, yrspromo, yrsmanager]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# this indicated there are no duplicate rows in the dataset
